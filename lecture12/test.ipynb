# %%
import pandas as pd
df = pd.read_csv('sitka_weather_07-2021_simple.csv')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'TAVG', 'TMAX', 'TMIN'], dtype='object')

# %%
df.head()
# Out:
#        STATION                  NAME        DATE  TAVG  TMAX  TMIN
# 0  USW00025333  SITKA AIRPORT, AK US  2021-07-01   NaN    61    53
# 1  USW00025333  SITKA AIRPORT, AK US  2021-07-02   NaN    60    52
# 2  USW00025333  SITKA AIRPORT, AK US  2021-07-03   NaN    66    54
# 3  USW00025333  SITKA AIRPORT, AK US  2021-07-04   NaN    60    55
# 4  USW00025333  SITKA AIRPORT, AK US  2021-07-05   NaN    65    55

# %%
df["TMAX"]
# Out:
# 0     61
# 1     60
# 2     66
# 3     60
# 4     65
# 5     59
# 6     58
# 7     58
# 8     57
# 9     60
# 10    60
# 11    60
# 12    57
# 13    58
# 14    60
# 15    61
# 16    63
# 17    63
# 18    70
# 19    64
# 20    59
# 21    63
# 22    61
# 23    58
# 24    59
# 25    64
# 26    62
# 27    70
# 28    70
# 29    73
# 30    66
# Name: TMAX, dtype: int64

# %%
df.loc[0]
# Out:
# STATION             USW00025333
# NAME       SITKA AIRPORT, AK US
# DATE                 2021-07-01
# TAVG                        NaN
# TMAX                         61
# TMIN                         53
# Name: 0, dtype: object

# %%
df.loc[:,'TAVG':'TMAX']   #查看连续多列
df.loc[:,['TAVG','TMAX']] #查看特定多列
df.loc[2:4,:]   # 查看连续多行 不是左闭右开
df.loc[[2,4],:] # 查看特定多行
# Out:
#        STATION                  NAME        DATE  TAVG  TMAX  TMIN
# 2  USW00025333  SITKA AIRPORT, AK US  2021-07-03   NaN    66    54
# 4  USW00025333  SITKA AIRPORT, AK US  2021-07-05   NaN    65    55

# %%
df.loc[:, 'difference'] = df["TMAX"] - df["TMIN"]

# %%
df
# Out:
#         STATION                  NAME        DATE  TAVG  TMAX  TMIN  \
# 0   USW00025333  SITKA AIRPORT, AK US  2021-07-01   NaN    61    53
# 1   USW00025333  SITKA AIRPORT, AK US  2021-07-02   NaN    60    52
# 2   USW00025333  SITKA AIRPORT, AK US  2021-07-03   NaN    66    54
# 3   USW00025333  SITKA AIRPORT, AK US  2021-07-04   NaN    60    55
# 4   USW00025333  SITKA AIRPORT, AK US  2021-07-05   NaN    65    55
# 5   USW00025333  SITKA AIRPORT, AK US  2021-07-06   NaN    59    54
# 6   USW00025333  SITKA AIRPORT, AK US  2021-07-07   NaN    58    53
# 7   USW00025333  SITKA AIRPORT, AK US  2021-07-08   NaN    58    53
# 8   USW00025333  SITKA AIRPORT, AK US  2021-07-09   NaN    57    53
# 9   USW00025333  SITKA AIRPORT, AK US  2021-07-10   NaN    60    51
# 10  USW00025333  SITKA AIRPORT, AK US  2021-07-11   NaN    60    51
# 11  USW00025333  SITKA AIRPORT, AK US  2021-07-12   NaN    60    54
# 12  USW00025333  SITKA AIRPORT, AK US  2021-07-13   NaN    57    52
# 13  USW00025333  SITKA AIRPORT, AK US  2021-07-14   NaN    58    51
# 14  USW00025333  SITKA AIRPORT, AK US  2021-07-15   NaN    60    50
# 15  USW00025333  SITKA AIRPORT, AK US  2021-07-16   NaN    61    54
# 16  USW00025333  SITKA AIRPORT, AK US  2021-07-17   NaN    63    56
# 17  USW00025333  SITKA AIRPORT, AK US  2021-07-18   NaN    63    57
# 18  USW00025333  SITKA AIRPORT, AK US  2021-07-19   NaN    70    55
# 19  USW00025333  SITKA AIRPORT, AK US  2021-07-20   NaN    64    56
# 20  USW00025333  SITKA AIRPORT, AK US  2021-07-21   NaN    59    54
# 21  USW00025333  SITKA AIRPORT, AK US  2021-07-22   NaN    63    55
# 22  USW00025333  SITKA AIRPORT, AK US  2021-07-23   NaN    61    56
# 23  USW00025333  SITKA AIRPORT, AK US  2021-07-24   NaN    58    54
# 24  USW00025333  SITKA AIRPORT, AK US  2021-07-25   NaN    59    52
# 25  USW00025333  SITKA AIRPORT, AK US  2021-07-26   NaN    64    49
# 26  USW00025333  SITKA AIRPORT, AK US  2021-07-27   NaN    62    57
# 27  USW00025333  SITKA AIRPORT, AK US  2021-07-28   NaN    70    52
# 28  USW00025333  SITKA AIRPORT, AK US  2021-07-29   NaN    70    52
# 29  USW00025333  SITKA AIRPORT, AK US  2021-07-30   NaN    73    60
# 30  USW00025333  SITKA AIRPORT, AK US  2021-07-31   NaN    66    48
#
#     difference
# 0            8
# 1            8
# 2           12
# 3            5
# 4           10
# 5            5
# 6            5
# 7            5
# 8            4
# 9            9
# 10           9
# 11           6
# 12           5
# 13           7
# 14          10
# 15           7
# 16           7
# 17           6
# 18          15
# 19           8
# 20           5
# 21           8
# 22           5
# 23           4
# 24           7
# 25          15
# 26           5
# 27          18
# 28          18
# 29          13
# 30          18

# %%
df.loc[:, 'y'] = range(31)

# %%
df_x = df.drop('difference', axis = 1)

# %%
df_60 = df[df["TMAX"] >= 60]
df_60
# Out:
#         STATION                  NAME        DATE  TAVG  TMAX  TMIN  \
# 0   USW00025333  SITKA AIRPORT, AK US  2021-07-01   NaN    61    53
# 1   USW00025333  SITKA AIRPORT, AK US  2021-07-02   NaN    60    52
# 2   USW00025333  SITKA AIRPORT, AK US  2021-07-03   NaN    66    54
# 3   USW00025333  SITKA AIRPORT, AK US  2021-07-04   NaN    60    55
# 4   USW00025333  SITKA AIRPORT, AK US  2021-07-05   NaN    65    55
# 9   USW00025333  SITKA AIRPORT, AK US  2021-07-10   NaN    60    51
# 10  USW00025333  SITKA AIRPORT, AK US  2021-07-11   NaN    60    51
# 11  USW00025333  SITKA AIRPORT, AK US  2021-07-12   NaN    60    54
# 14  USW00025333  SITKA AIRPORT, AK US  2021-07-15   NaN    60    50
# 15  USW00025333  SITKA AIRPORT, AK US  2021-07-16   NaN    61    54
# 16  USW00025333  SITKA AIRPORT, AK US  2021-07-17   NaN    63    56
# 17  USW00025333  SITKA AIRPORT, AK US  2021-07-18   NaN    63    57
# 18  USW00025333  SITKA AIRPORT, AK US  2021-07-19   NaN    70    55
# 19  USW00025333  SITKA AIRPORT, AK US  2021-07-20   NaN    64    56
# 21  USW00025333  SITKA AIRPORT, AK US  2021-07-22   NaN    63    55
# 22  USW00025333  SITKA AIRPORT, AK US  2021-07-23   NaN    61    56
# 25  USW00025333  SITKA AIRPORT, AK US  2021-07-26   NaN    64    49
# 26  USW00025333  SITKA AIRPORT, AK US  2021-07-27   NaN    62    57
# 27  USW00025333  SITKA AIRPORT, AK US  2021-07-28   NaN    70    52
# 28  USW00025333  SITKA AIRPORT, AK US  2021-07-29   NaN    70    52
# 29  USW00025333  SITKA AIRPORT, AK US  2021-07-30   NaN    73    60
# 30  USW00025333  SITKA AIRPORT, AK US  2021-07-31   NaN    66    48
#
#     difference   y
# 0            8   0
# 1            8   1
# 2           12   2
# 3            5   3
# 4           10   4
# 9            9   9
# 10           9  10
# 11           6  11
# 14          10  14
# 15           7  15
# 16           7  16
# 17           6  17
# 18          15  18
# 19           8  19
# 21           8  21
# 22           5  22
# 25          15  25
# 26           5  26
# 27          18  27
# 28          18  28
# 29          13  29
# 30          18  30

# %%
from matplotlib import pyplot as plt
# Plot the high temperatures.
fig, ax = plt.subplots()
ax.plot(df["TMAX"], c='red')
# Format plot.
ax.set_title("Daily high temperatures, July 2021", fontsize=24)
ax.set_xlabel('', fontsize=16)
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)
plt.savefig('simple.jpg',bbox_inches='tight',dpi=300)

# %%
# convert string to time format
df.loc[:,'date'] = pd.to_datetime(df['DATE'])

# %%
# filtering data by date
df_t = df[(df['date']>="20210715") & (df['date']<="20210720")]
df_t
# Out:
#         STATION                  NAME        DATE  TAVG  TMAX  TMIN  \
# 14  USW00025333  SITKA AIRPORT, AK US  2021-07-15   NaN    60    50
# 15  USW00025333  SITKA AIRPORT, AK US  2021-07-16   NaN    61    54
# 16  USW00025333  SITKA AIRPORT, AK US  2021-07-17   NaN    63    56
# 17  USW00025333  SITKA AIRPORT, AK US  2021-07-18   NaN    63    57
# 18  USW00025333  SITKA AIRPORT, AK US  2021-07-19   NaN    70    55
# 19  USW00025333  SITKA AIRPORT, AK US  2021-07-20   NaN    64    56
#
#     difference   y       date
# 14          10  14 2021-07-15
# 15           7  15 2021-07-16
# 16           7  16 2021-07-17
# 17           6  17 2021-07-18
# 18          15  18 2021-07-19
# 19           8  19 2021-07-20

# %%
# calculate periods
periods = df.loc[20, "date"] - df.loc[1, "date"]
periods.days
# Out:
# 19

# %%
df.loc[:,'date'] = pd.to_datetime(df['DATE'])
fig, ax = plt.subplots()
ax.plot(df["date"], df["TMAX"], c='red')
ax.set_title("Daily high temperatures, July 2021", fontsize=18)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=10)
plt.savefig('simple.jpg',bbox_inches='tight',dpi=300)

# %%
import pandas as pd
df = pd.read_csv('sitka_weather_2021_simple.csv')
df.loc[:,'date'] = pd.to_datetime(df['DATE'])
# Plot data.
fig, ax = plt.subplots()
ax.plot(df["date"], df["TMAX"], c='red', alpha=0.5)
ax.plot(df["date"], df["TMIN"], c='blue', alpha=0.5)
ax.fill_between(df["date"], df["TMAX"], df["TMIN"], facecolor='blue', alpha=0.1)
# Format plot.
ax.set_title("Daily high and low temperatures - 2021", fontsize=18)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=10)
plt.savefig('simple.jpg',bbox_inches='tight',dpi=300)

# %%
import pandas as pd
from matplotlib import pyplot as plt
frame = pd.read_csv('death_valley_2021_simple.csv')

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  365 non-null    object
#  1   NAME     365 non-null    object
#  2   DATE     365 non-null    object
#  3   TMAX     364 non-null    float64
#  4   TMIN     365 non-null    int64
#  5   TOBS     360 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 17.2+ KB

# %%
frame[frame["TMAX"].isna()]
# Out:
#          STATION                               NAME        DATE  TMAX  TMIN  \
# 123  USC00042319  DEATH VALLEY NATIONAL PARK, CA US  2021-05-04   NaN    72
#
#      TOBS
# 123  89.0

# %%
frame_DT = frame[["DATE", "TMAX", "TMIN"]]
frame_cleaned = frame_DT.dropna()
frame_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 364 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    364 non-null    object
#  1   TMAX    364 non-null    float64
#  2   TMIN    364 non-null    int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.4+ KB

# %%
from pathlib import Path
import pandas as pd
import json
path = Path('btc_close_2017.json')
contents = path.read_text()
btc_data = json.loads(contents)
date = [];close=[]; months=[]
for btc_dict in btc_data:
    months.append(int(btc_dict['month']))
    close.append(float(btc_dict['close']))
    date.append(btc_dict['date'])
df = pd.DataFrame({"close": close, "months": months, "date": date})
df.loc[:,'date'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#            close  months                 date
# 0      6928.6492       1  2017-01-01 00:00:00
# 1      7070.2554       1  2017-01-02 00:00:00
# 2      7175.1082       1  2017-01-03 00:00:00
# 3      7835.7615       1  2017-01-04 00:00:00
# 4      6928.7578       1  2017-01-05 00:00:00
# ..           ...     ...                  ...
# 341  106233.2010      12  2017-12-08 00:00:00
# 342   98676.7747      12  2017-12-09 00:00:00
# 343   99525.1027      12  2017-12-10 00:00:00
# 344  110642.8800      12  2017-12-11 00:00:00
# 345  113732.6745      12  2017-12-12 00:00:00
#
# [346 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(df['date'],df['close'], linewidth=0.5, c='red')
ax.scatter(date,close, s=5, c='red')
ax.set_title('Close',fontsize=10)
fig.autofmt_xdate()
plt.savefig('close.jpg',dpi=300)

# %%
monthly_avg = df.groupby('months')['close'].mean()
monthly_avg
# Out:
# months
# 1      6286.407239
# 2      7316.194804
# 3      7789.560697
# 4      8390.903147
# 5     12964.346574
# 6     18092.539340
# 7     17146.636694
# 8     26093.248200
# 9     26866.092197
# 10    35461.165313
# 11    51436.664547
# 12    91936.948367
# Name: close, dtype: float64

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(monthly_avg.index, monthly_avg.values, linewidth=1)
ax.scatter(monthly_avg.index, monthly_avg.values, s=20)
ax.set_title('Close',fontsize=10)
plt.savefig('monthly_avg.jpg',dpi=300)

# %%
from pathlib import Path
import pandas as pd
import json
path = Path('/Users/wangwanglulu/GitHub/workstation/lecture12/pop/China.json')
contents = path.read_text()
data = json.loads(contents)

# %%
data
# Out:
# [{'date': 2024, 'value': 1408975000, 'country': 'CHN'},
#  {'date': 2023, 'value': 1410710000, 'country': 'CHN'},
#  {'date': 2022, 'value': 1412175000, 'country': 'CHN'},
#  {'date': 2021, 'value': 1412360000, 'country': 'CHN'},
#  {'date': 2020, 'value': 1411100000, 'country': 'CHN'},
#  {'date': 2019, 'value': 1407745000, 'country': 'CHN'},
#  {'date': 2018, 'value': 1402760000, 'country': 'CHN'},
#  {'date': 2017, 'value': 1396215000, 'country': 'CHN'},
#  {'date': 2016, 'value': 1387790000, 'country': 'CHN'},
#  {'date': 2015, 'value': 1379860000, 'country': 'CHN'},
#  {'date': 2014, 'value': 1371860000, 'country': 'CHN'},
#  {'date': 2013, 'value': 1363240000, 'country': 'CHN'},
#  {'date': 2012, 'value': 1354190000, 'country': 'CHN'},
#  {'date': 2011, 'value': 1345035000, 'country': 'CHN'},
#  {'date': 2010, 'value': 1337705000, 'country': 'CHN'},
#  {'date': 2009, 'value': 1331260000, 'country': 'CHN'},
#  {'date': 2008, 'value': 1324655000, 'country': 'CHN'},
#  {'date': 2007, 'value': 1317885000, 'country': 'CHN'},
#  {'date': 2006, 'value': 1311020000, 'country': 'CHN'},
#  {'date': 2005, 'value': 1303720000, 'country': 'CHN'},
#  {'date': 2004, 'value': 1296075000, 'country': 'CHN'},
#  {'date': 2003, 'value': 1288400000, 'country': 'CHN'},
#  {'date': 2002, 'value': 1280400000, 'country': 'CHN'},
#  {'date': 2001, 'value': 1271850000, 'country': 'CHN'},
#  {'date': 2000, 'value': 1262645000, 'country': 'CHN'},
#  {'date': 1999, 'value': 1252735000, 'country': 'CHN'},
#  {'date': 1998, 'value': 1241935000, 'country': 'CHN'},
#  {'date': 1997, 'value': 1230075000, 'country': 'CHN'},
#  {'date': 1996, 'value': 1217550000, 'country': 'CHN'},
#  {'date': 1995, 'value': 1204855000, 'country': 'CHN'},
#  {'date': 1994, 'value': 1191835000, 'country': 'CHN'},
#  {'date': 1993, 'value': 1178440000, 'country': 'CHN'},
#  {'date': 1992, 'value': 1164970000, 'country': 'CHN'},
#  {'date': 1991, 'value': 1150780000, 'country': 'CHN'},
#  {'date': 1990, 'value': 1135185000, 'country': 'CHN'},
#  {'date': 1989, 'value': 1118650000, 'country': 'CHN'},
#  {'date': 1988, 'value': 1101630000, 'country': 'CHN'},
#  {'date': 1987, 'value': 1084035000, 'country': 'CHN'},
#  {'date': 1986, 'value': 1066790000, 'country': 'CHN'},
#  {'date': 1985, 'value': 1051040000, 'country': 'CHN'},
#  {'date': 1984, 'value': 1036825000, 'country': 'CHN'},
#  {'date': 1983, 'value': 1023310000, 'country': 'CHN'},
#  {'date': 1982, 'value': 1008630000, 'country': 'CHN'},
#  {'date': 1981, 'value': 993885000, 'country': 'CHN'},
#  {'date': 1980, 'value': 981235000, 'country': 'CHN'},
#  {'date': 1979, 'value': 969005000, 'country': 'CHN'},
#  {'date': 1978, 'value': 956165000, 'country': 'CHN'},
#  {'date': 1977, 'value': 943455000, 'country': 'CHN'},
#  {'date': 1976, 'value': 930685000, 'country': 'CHN'},
#  {'date': 1975, 'value': 916395000, 'country': 'CHN'},
#  {'date': 1974, 'value': 900350000, 'country': 'CHN'},
#  {'date': 1973, 'value': 881940000, 'country': 'CHN'},
#  {'date': 1972, 'value': 862030000, 'country': 'CHN'},
#  {'date': 1971, 'value': 841105000, 'country': 'CHN'},
#  {'date': 1970, 'value': 818315000, 'country': 'CHN'},
#  {'date': 1969, 'value': 796025000, 'country': 'CHN'},
#  {'date': 1968, 'value': 774510000, 'country': 'CHN'},
#  {'date': 1967, 'value': 754550000, 'country': 'CHN'},
#  {'date': 1966, 'value': 735400000, 'country': 'CHN'},
#  {'date': 1965, 'value': 715185000, 'country': 'CHN'},
#  {'date': 1964, 'value': 698355000, 'country': 'CHN'},
#  {'date': 1963, 'value': 682335000, 'country': 'CHN'},
#  {'date': 1962, 'value': 665770000, 'country': 'CHN'},
#  {'date': 1961, 'value': 660330000, 'country': 'CHN'},
#  {'date': 1960, 'value': 667070000, 'country': 'CHN'}]

# %%
year = [];  pop = []
for x in data:
    year.append(x['date'])
    pop.append(x['value'])
df_C = df.DataFrame({"year": year, "pop": pop})
df_C.loc[:,'year'] = pd.to_datetime(df_C['year'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/0z/4mw4j67165b0n7cxb0j02sch0000gn/T/ipykernel_26834/3330884333.py in ?()
#       1 year = [];  pop = []
#       2 for x in data:
#       3     year.append(x['date'])
#       4     pop.append(x['value'])
# ----> 5 df_C = df.DataFrame({"year": year, "pop": pop})
#       6 df_C.loc[:,'year'] = pd.to_datetime(df_C['year'])
#       7
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'
