# %%
import pandas as pd
 
df = pd.read_csv('sitka_weather_07-2021_simple.csv')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.columns
# Out:
# Index(['STATION', 'NAME', 'DATE', 'TAVG', 'TMAX', 'TMIN'], dtype='object')

# %%
df.head()
# Out:
#        STATION                  NAME        DATE  TAVG  TMAX  TMIN
# 0  USW00025333  SITKA AIRPORT, AK US  2021-07-01   NaN    61    53
# 1  USW00025333  SITKA AIRPORT, AK US  2021-07-02   NaN    60    52
# 2  USW00025333  SITKA AIRPORT, AK US  2021-07-03   NaN    66    54
# 3  USW00025333  SITKA AIRPORT, AK US  2021-07-04   NaN    60    55
# 4  USW00025333  SITKA AIRPORT, AK US  2021-07-05   NaN    65    55

# %%
df["TMAX"]
# Out:
# 0     61
# 1     60
# 2     66
# 3     60
# 4     65
# 5     59
# 6     58
# 7     58
# 8     57
# 9     60
# 10    60
# 11    60
# 12    57
# 13    58
# 14    60
# 15    61
# 16    63
# 17    63
# 18    70
# 19    64
# 20    59
# 21    63
# 22    61
# 23    58
# 24    59
# 25    64
# 26    62
# 27    70
# 28    70
# 29    73
# 30    66
# Name: TMAX, dtype: int64

# %%
df.loc[0]
# Out:
# date      2017-01-01
# close           6928
# months             1
# Name: 0, dtype: object

# %%
from matplotlib import pyplot as plt

# Plot the high temperatures.
fig, ax = plt.subplots()
ax.plot(df["TMAX"], c='red')

# Format plot.
ax.set_title("Daily high temperatures, July 2021", fontsize=24)
ax.set_xlabel('', fontsize=16)
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.savefig('simple.jpg',bbox_inches='tight',dpi=300)

# %%
df['date'] = pd.to_datetime(df['DATE'])
df_t = df[(df['date']>="20210715") & (df['date']<="20210720")]
periods = df.loc[1, "date"] - df.loc[20, "date"]
periods.days
# Out:
# -19

# %%
fig, ax = plt.subplots()
ax.plot(df["date"], df["TMAX"], c='red')

ax.set_title("Daily high temperatures, July 2021", fontsize=18)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=10)

plt.savefig('simple.jpg',bbox_inches='tight',dpi=300)

# %%
# Plot data.
fig, ax = plt.subplots()
ax.plot(df["date"], df["TMAX"], c='red', alpha=0.5)
ax.plot(df["date"], df["TMIN"], c='blue', alpha=0.5)
ax.fill_between(df["date"], df["TMAX"], df["TMIN"], facecolor='blue', alpha=0.1)

# Format plot.
ax.set_title("Daily high and low temperatures - 2021", fontsize=18)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=10)

plt.savefig('simple.jpg',bbox_inches='tight',dpi=300)

# %%
import pandas as pd
 
df = pd.read_csv('sitka_weather_2021_simple.csv')
df['date'] = pd.to_datetime(df['DATE'])

# Plot data.
fig, ax = plt.subplots()
ax.plot(df["date"], df["TMAX"], c='red', alpha=0.5)
ax.plot(df["date"], df["TMIN"], c='blue', alpha=0.5)
ax.fill_between(df["date"], df["TMAX"], df["TMIN"], facecolor='blue', alpha=0.1)

# Format plot.
ax.set_title("Daily high and low temperatures - 2021", fontsize=18)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=10)

plt.savefig('simple.jpg',bbox_inches='tight',dpi=300)

# %%
import pandas as pd
from numpy import nan as NA
from matplotlib import pyplot as plt

frame = pd.read_csv('death_valley_2021_simple.csv')

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  365 non-null    object
#  1   NAME     365 non-null    object
#  2   DATE     365 non-null    object
#  3   TMAX     364 non-null    float64
#  4   TMIN     365 non-null    int64
#  5   TOBS     360 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 17.2+ KB

# %%
frame[frame["TMAX"].isna()]
# Out:
#          STATION                               NAME        DATE  TMAX  TMIN  \
# 123  USC00042319  DEATH VALLEY NATIONAL PARK, CA US  2021-05-04   NaN    72
#
#      TOBS
# 123  89.0

# %%
frame_DT= frame[["DATE", "TMAX", "TMIN"]]

# %%
frame_DT = frame[["DATE", "TMAX", "TMIN"]]
fc = frame_DT.dropna()
fc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 364 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    364 non-null    object
#  1   TMAX    364 non-null    float64
#  2   TMIN    364 non-null    int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.4+ KB

# %%
fc.loc[:,'date'] = pd.to_datetime(fc['DATE'])

# Plot data.
fig, ax = plt.subplots()
ax.plot(fc["date"], fc["TMAX"], c='red', alpha=0.5)
ax.plot(fc["date"], fc["TMIN"], c='blue', alpha=0.5)
ax.fill_between(fc["date"], fc["TMAX"], fc["TMIN"], facecolor='blue', alpha=0.1)

# Format plot.
ax.set_title("Daily high and low temperatures - 2021", fontsize=18)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=10)

plt.savefig('simple.jpg',bbox_inches='tight',dpi=300)
# Out:
# /var/folders/0z/4mw4j67165b0n7cxb0j02sch0000gn/T/ipykernel_23609/3777326105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fc.loc[:,'date'] = pd.to_datetime(fc['DATE'])

# %%
from pathlib import Path
import pandas as pd
import json

path = Path('btc_close_2017.json')
contents = path.read_text()
btc_data = json.loads(contents)

date=[]; close=[]; months=[]

for btc_dict in btc_data:
    date.append(btc_dict['date'])
    months.append(int(btc_dict['month']))
    close.append(int(float(btc_dict['close'])))

# %%
df.loc[2:4,:]
# Out:
#        STATION                  NAME        DATE  TAVG  TMAX  TMIN       date
# 2  USW00025333  SITKA AIRPORT, AK US  2021-01-03   NaN    43    36 2021-01-03
# 3  USW00025333  SITKA AIRPORT, AK US  2021-01-04   NaN    45    39 2021-01-04
# 4  USW00025333  SITKA AIRPORT, AK US  2021-01-05   NaN    45    40 2021-01-05

# %%
from pathlib import Path
import pandas as pd
import json

path = Path('btc_close_2017.json')
contents = path.read_text()
btc_data = json.loads(contents)

date=[]; close=[]; months=[]

for btc_dict in btc_data:
    date.append(btc_dict['date'])
    months.append(int(btc_dict['month']))
    close.append(int(float(btc_dict['close'])))

data = {"date": date, "close": close, "months": months}
df = pd.DataFrame(data)
df[:,'date'] = pd.to_datetime(df['date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (slice(None, None, None), 'date')
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[20], line 18
#      16 data = {"date": date, "close": close, "months": months}
#      17 df = pd.DataFrame(data)
# ---> 18 df[:,'date'] = pd.to_datetime(df['date'])
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:4538, in DataFrame._set_item(self, key, value)
#    4535             value = np.tile(value, (len(existing_piece.columns), 1)).T
#    4536             refs = None
# -> 4538 self._set_item_mgr(key, value, refs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:4485, in DataFrame._set_item_mgr(self, key, value, refs)
#    4481 def _set_item_mgr(
#    4482     self, key, value: ArrayLike, refs: BlockValuesRefs | None = None
#    4483 ) -> None:
#    4484     try:
# -> 4485         loc = self._info_axis.get_loc(key)
#    4486     except KeyError:
#    4487         # This item wasn't present, just insert at end
#    4488         self._mgr.insert(len(self._info_axis), key, value, refs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3811, in Index.get_loc(self, key)
#    3806 except KeyError as err:
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
# -> 3811         raise InvalidIndexError(key)
#    3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# InvalidIndexError: (slice(None, None, None), 'date')

# %%
df
# Out:
#            date   close  months
# 0    2017-01-01    6928       1
# 1    2017-01-02    7070       1
# 2    2017-01-03    7175       1
# 3    2017-01-04    7835       1
# 4    2017-01-05    6928       1
# ..          ...     ...     ...
# 341  2017-12-08  106233      12
# 342  2017-12-09   98676      12
# 343  2017-12-10   99525      12
# 344  2017-12-11  110642      12
# 345  2017-12-12  113732      12
#
# [346 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(df['date'],df['close'], linewidth=0.5, c='red')
ax.scatter(date,close, s=5, c='red')
ax.set_title('Close',fontsize=10)
fig.autofmt_xdate()

plt.savefig('close.jpg',dpi=300)

# %%
import os
import json
from pathlib import Path
folder_path = "/Users/wangwanglulu/GitHub/workstation/lecture12/pop"
summary = {}
for filename in os.listdir(folder_path): 
    path = Path(os.path.join(folder_path, filename))
    contents = path.read_text(errors="ignore")
    summary[filename] = json.loads(contents)
date = []; pop = []; ds = {}
for x, z in summary.items():
    for y in z:
        date.append(y['date'])
        pop.append(y['value'])
    ds[x] = pd.DataFrame({"date": date, "pop": pop})
# Out:
# {'China.json': [{'date': 2024, 'value': 1408975000, 'country': 'CHN'},
#   {'date': 2023, 'value': 1410710000, 'country': 'CHN'},
#   {'date': 2022, 'value': 1412175000, 'country': 'CHN'},
#   {'date': 2021, 'value': 1412360000, 'country': 'CHN'},
#   {'date': 2020, 'value': 1411100000, 'country': 'CHN'},
#   {'date': 2019, 'value': 1407745000, 'country': 'CHN'},
#   {'date': 2018, 'value': 1402760000, 'country': 'CHN'},
#   {'date': 2017, 'value': 1396215000, 'country': 'CHN'},
#   {'date': 2016, 'value': 1387790000, 'country': 'CHN'},
#   {'date': 2015, 'value': 1379860000, 'country': 'CHN'},
#   {'date': 2014, 'value': 1371860000, 'country': 'CHN'},
#   {'date': 2013, 'value': 1363240000, 'country': 'CHN'},
#   {'date': 2012, 'value': 1354190000, 'country': 'CHN'},
#   {'date': 2011, 'value': 1345035000, 'country': 'CHN'},
#   {'date': 2010, 'value': 1337705000, 'country': 'CHN'},
#   {'date': 2009, 'value': 1331260000, 'country': 'CHN'},
#   {'date': 2008, 'value': 1324655000, 'country': 'CHN'},
#   {'date': 2007, 'value': 1317885000, 'country': 'CHN'},
#   {'date': 2006, 'value': 1311020000, 'country': 'CHN'},
#   {'date': 2005, 'value': 1303720000, 'country': 'CHN'},
#   {'date': 2004, 'value': 1296075000, 'country': 'CHN'},
#   {'date': 2003, 'value': 1288400000, 'country': 'CHN'},
#   {'date': 2002, 'value': 1280400000, 'country': 'CHN'},
#   {'date': 2001, 'value': 1271850000, 'country': 'CHN'},
#   {'date': 2000, 'value': 1262645000, 'country': 'CHN'},
#   {'date': 1999, 'value': 1252735000, 'country': 'CHN'},
#   {'date': 1998, 'value': 1241935000, 'country': 'CHN'},
#   {'date': 1997, 'value': 1230075000, 'country': 'CHN'},
#   {'date': 1996, 'value': 1217550000, 'country': 'CHN'},
#   {'date': 1995, 'value': 1204855000, 'country': 'CHN'},
#   {'date': 1994, 'value': 1191835000, 'country': 'CHN'},
#   {'date': 1993, 'value': 1178440000, 'country': 'CHN'},
#   {'date': 1992, 'value': 1164970000, 'country': 'CHN'},
#   {'date': 1991, 'value': 1150780000, 'country': 'CHN'},
#   {'date': 1990, 'value': 1135185000, 'country': 'CHN'},
#   {'date': 1989, 'value': 1118650000, 'country': 'CHN'},
#   {'date': 1988, 'value': 1101630000, 'country': 'CHN'},
#   {'date': 1987, 'value': 1084035000, 'country': 'CHN'},
#   {'date': 1986, 'value': 1066790000, 'country': 'CHN'},
#   {'date': 1985, 'value': 1051040000, 'country': 'CHN'},
#   {'date': 1984, 'value': 1036825000, 'country': 'CHN'},
#   {'date': 1983, 'value': 1023310000, 'country': 'CHN'},
#   {'date': 1982, 'value': 1008630000, 'country': 'CHN'},
#   {'date': 1981, 'value': 993885000, 'country': 'CHN'},
#   {'date': 1980, 'value': 981235000, 'country': 'CHN'},
#   {'date': 1979, 'value': 969005000, 'country': 'CHN'},
#   {'date': 1978, 'value': 956165000, 'country': 'CHN'},
#   {'date': 1977, 'value': 943455000, 'country': 'CHN'},
#   {'date': 1976, 'value': 930685000, 'country': 'CHN'},
#   {'date': 1975, 'value': 916395000, 'country': 'CHN'},
#   {'date': 1974, 'value': 900350000, 'country': 'CHN'},
#   {'date': 1973, 'value': 881940000, 'country': 'CHN'},
#   {'date': 1972, 'value': 862030000, 'country': 'CHN'},
#   {'date': 1971, 'value': 841105000, 'country': 'CHN'},
#   {'date': 1970, 'value': 818315000, 'country': 'CHN'},
#   {'date': 1969, 'value': 796025000, 'country': 'CHN'},
#   {'date': 1968, 'value': 774510000, 'country': 'CHN'},
#   {'date': 1967, 'value': 754550000, 'country': 'CHN'},
#   {'date': 1966, 'value': 735400000, 'country': 'CHN'},
#   {'date': 1965, 'value': 715185000, 'country': 'CHN'},
#   {'date': 1964, 'value': 698355000, 'country': 'CHN'},
#   {'date': 1963, 'value': 682335000, 'country': 'CHN'},
#   {'date': 1962, 'value': 665770000, 'country': 'CHN'},
#   {'date': 1961, 'value': 660330000, 'country': 'CHN'},
#   {'date': 1960, 'value': 667070000, 'country': 'CHN'}],
#  'Indian.json': [{'date': 2024, 'value': 1450935791, 'country': 'IND'},
#   {'date': 2023, 'value': 1438069596, 'country': 'IND'},
#   {'date': 2022, 'value': 1425423212, 'country': 'IND'},
#   {'date': 2021, 'value': 1414203896, 'country': 'IND'},
#   {'date': 2020, 'value': 1402617695, 'country': 'IND'},
#   {'date': 2019, 'value': 1389030312, 'country': 'IND'},
#   {'date': 2018, 'value': 1374659064, 'country': 'IND'},
#   {'date': 2017, 'value': 1359657400, 'country': 'IND'},
#   {'date': 2016, 'value': 1343944296, 'country': 'IND'},
#   {'date': 2015, 'value': 1328024498, 'country': 'IND'},
#   {'date': 2014, 'value': 1312277191, 'country': 'IND'},
#   {'date': 2013, 'value': 1295829511, 'country': 'IND'},
#   {'date': 2012, 'value': 1278674502, 'country': 'IND'},
#   {'date': 2011, 'value': 1261224954, 'country': 'IND'},
#   {'date': 2010, 'value': 1243481564, 'country': 'IND'},
#   {'date': 2009, 'value': 1225524753, 'country': 'IND'},
#   {'date': 2008, 'value': 1207930964, 'country': 'IND'},
#   {'date': 2007, 'value': 1190676021, 'country': 'IND'},
#   {'date': 2006, 'value': 1172878890, 'country': 'IND'},
#   {'date': 2005, 'value': 1154676322, 'country': 'IND'},
#   {'date': 2004, 'value': 1135991513, 'country': 'IND'},
#   {'date': 2003, 'value': 1116803006, 'country': 'IND'},
#   {'date': 2002, 'value': 1097600380, 'country': 'IND'},
#   {'date': 2001, 'value': 1077898575, 'country': 'IND'},
#   {'date': 2000, 'value': 1057922733, 'country': 'IND'},
#   {'date': 1999, 'value': 1038225823, 'country': 'IND'},
#   {'date': 1998, 'value': 1018665080, 'country': 'IND'},
#   {'date': 1997, 'value': 999133762, 'country': 'IND'},
#   {'date': 1996, 'value': 979678458, 'country': 'IND'},
#   {'date': 1995, 'value': 960301044, 'country': 'IND'},
#   {'date': 1994, 'value': 941163767, 'country': 'IND'},
#   {'date': 1993, 'value': 922118387, 'country': 'IND'},
#   {'date': 1992, 'value': 902957070, 'country': 'IND'},
#   {'date': 1991, 'value': 883927600, 'country': 'IND'},
#   {'date': 1990, 'value': 864972221, 'country': 'IND'},
#   {'date': 1989, 'value': 846039529, 'country': 'IND'},
#   {'date': 1988, 'value': 827342990, 'country': 'IND'},
#   {'date': 1987, 'value': 808931270, 'country': 'IND'},
#   {'date': 1986, 'value': 790689978, 'country': 'IND'},
#   {'date': 1985, 'value': 772647793, 'country': 'IND'},
#   {'date': 1984, 'value': 754875449, 'country': 'IND'},
#   {'date': 1983, 'value': 737372681, 'country': 'IND'},
#   {'date': 1982, 'value': 720313473, 'country': 'IND'},
#   {'date': 1981, 'value': 703696250, 'country': 'IND'},
#   {'date': 1980, 'value': 687354025, 'country': 'IND'},
#   {'date': 1979, 'value': 671155747, 'country': 'IND'},
#   {'date': 1978, 'value': 655728229, 'country': 'IND'},
#   {'date': 1977, 'value': 640801103, 'country': 'IND'},
#   {'date': 1976, 'value': 625861883, 'country': 'IND'},
#   {'date': 1975, 'value': 611309535, 'country': 'IND'},
#   {'date': 1974, 'value': 597041391, 'country': 'IND'},
#   {'date': 1973, 'value': 583465598, 'country': 'IND'},
#   {'date': 1972, 'value': 570482142, 'country': 'IND'},
#   {'date': 1971, 'value': 558096387, 'country': 'IND'},
#   {'date': 1970, 'value': 545864268, 'country': 'IND'},
#   {'date': 1969, 'value': 533880544, 'country': 'IND'},
#   {'date': 1968, 'value': 522716889, 'country': 'IND'},
#   {'date': 1967, 'value': 511606372, 'country': 'IND'},
#   {'date': 1966, 'value': 500740247, 'country': 'IND'},
#   {'date': 1965, 'value': 490140146, 'country': 'IND'},
#   {'date': 1964, 'value': 479229598, 'country': 'IND'},
#   {'date': 1963, 'value': 468138575, 'country': 'IND'},
#   {'date': 1962, 'value': 457283090, 'country': 'IND'},
#   {'date': 1961, 'value': 446564729, 'country': 'IND'},
#   {'date': 1960, 'value': 435990338, 'country': 'IND'}],
#  'USA.json': [{'date': 2024, 'value': 340110988, 'country': 'USA'},
#   {'date': 2023, 'value': 336806231, 'country': 'USA'},
#   {'date': 2022, 'value': 334017321, 'country': 'USA'},
#   {'date': 2021, 'value': 332099760, 'country': 'USA'},
#   {'date': 2020, 'value': 331577720, 'country': 'USA'},
#   {'date': 2019, 'value': 330226227, 'country': 'USA'},
#   {'date': 2018, 'value': 328529577, 'country': 'USA'},
#   {'date': 2017, 'value': 326608609, 'country': 'USA'},
#   {'date': 2016, 'value': 324353340, 'country': 'USA'},
#   {'date': 2015, 'value': 321815121, 'country': 'USA'},
#   {'date': 2014, 'value': 319257560, 'country': 'USA'},
#   {'date': 2013, 'value': 316726282, 'country': 'USA'},
#   {'date': 2012, 'value': 314339099, 'country': 'USA'},
#   {'date': 2011, 'value': 311839461, 'country': 'USA'},
#   {'date': 2010, 'value': 309378227, 'country': 'USA'},
#   {'date': 2009, 'value': 306771529, 'country': 'USA'},
#   {'date': 2008, 'value': 304093966, 'country': 'USA'},
#   {'date': 2007, 'value': 301231207, 'country': 'USA'},
#   {'date': 2006, 'value': 298379912, 'country': 'USA'},
#   {'date': 2005, 'value': 295516599, 'country': 'USA'},
#   {'date': 2004, 'value': 292805298, 'country': 'USA'},
#   {'date': 2003, 'value': 290107933, 'country': 'USA'},
#   {'date': 2002, 'value': 287625193, 'country': 'USA'},
#   {'date': 2001, 'value': 284968955, 'country': 'USA'},
#   {'date': 2000, 'value': 282162411, 'country': 'USA'},
#   {'date': 1999, 'value': 279040000, 'country': 'USA'},
#   {'date': 1998, 'value': 275854000, 'country': 'USA'},
#   {'date': 1997, 'value': 272657000, 'country': 'USA'},
#   {'date': 1996, 'value': 269394000, 'country': 'USA'},
#   {'date': 1995, 'value': 266278000, 'country': 'USA'},
#   {'date': 1994, 'value': 263126000, 'country': 'USA'},
#   {'date': 1993, 'value': 259919000, 'country': 'USA'},
#   {'date': 1992, 'value': 256514000, 'country': 'USA'},
#   {'date': 1991, 'value': 252981000, 'country': 'USA'},
#   {'date': 1990, 'value': 249623000, 'country': 'USA'},
#   {'date': 1989, 'value': 246819000, 'country': 'USA'},
#   {'date': 1988, 'value': 244499000, 'country': 'USA'},
#   {'date': 1987, 'value': 242289000, 'country': 'USA'},
#   {'date': 1986, 'value': 240133000, 'country': 'USA'},
#   {'date': 1985, 'value': 237924000, 'country': 'USA'},
#   {'date': 1984, 'value': 235825000, 'country': 'USA'},
#   {'date': 1983, 'value': 233792000, 'country': 'USA'},
#   {'date': 1982, 'value': 231664000, 'country': 'USA'},
#   {'date': 1981, 'value': 229466000, 'country': 'USA'},
#   {'date': 1980, 'value': 227225000, 'country': 'USA'},
#   {'date': 1979, 'value': 225055000, 'country': 'USA'},
#   {'date': 1978, 'value': 222585000, 'country': 'USA'},
#   {'date': 1977, 'value': 220239000, 'country': 'USA'},
#   {'date': 1976, 'value': 218035000, 'country': 'USA'},
#   {'date': 1975, 'value': 215973000, 'country': 'USA'},
#   {'date': 1974, 'value': 213854000, 'country': 'USA'},
#   {'date': 1973, 'value': 211909000, 'country': 'USA'},
#   {'date': 1972, 'value': 209896000, 'country': 'USA'},
#   {'date': 1971, 'value': 207661000, 'country': 'USA'},
#   {'date': 1970, 'value': 205052000, 'country': 'USA'},
#   {'date': 1969, 'value': 202677000, 'country': 'USA'},
#   {'date': 1968, 'value': 200706000, 'country': 'USA'},
#   {'date': 1967, 'value': 198712000, 'country': 'USA'},
#   {'date': 1966, 'value': 196560000, 'country': 'USA'},
#   {'date': 1965, 'value': 194303000, 'country': 'USA'},
#   {'date': 1964, 'value': 191889000, 'country': 'USA'},
#   {'date': 1963, 'value': 189242000, 'country': 'USA'},
#   {'date': 1962, 'value': 186538000, 'country': 'USA'},
#   {'date': 1961, 'value': 183691000, 'country': 'USA'},
#   {'date': 1960, 'value': 180671000, 'country': 'USA'}]}

# %%
ds = {}
for x, z in summary.items():
    date = []; pop = []; 
    for y in z:
        date.append(y['date'])
        pop.append(y['value'])
    ds[x] = pd.DataFrame({"date": date, "pop": pop})

# %%
df_C= ds['China.json']
df_I = ds['Indian.json']

# %%
df_I
# Out:
#     date         pop
# 0   2024  1450935791
# 1   2023  1438069596
# 2   2022  1425423212
# 3   2021  1414203896
# 4   2020  1402617695
# ..   ...         ...
# 60  1964   479229598
# 61  1963   468138575
# 62  1962   457283090
# 63  1961   446564729
# 64  1960   435990338
#
# [65 rows x 2 columns]

# %%
df_m = pd.merge(df_C, df_I, on='date',\
                suffixes=["_C","_I"])
df_m
# Out:
#     date       pop_C       pop_I
# 0   2024  1408975000  1450935791
# 1   2023  1410710000  1438069596
# 2   2022  1412175000  1425423212
# 3   2021  1412360000  1414203896
# 4   2020  1411100000  1402617695
# ..   ...         ...         ...
# 60  1964   698355000   479229598
# 61  1963   682335000   468138575
# 62  1962   665770000   457283090
# 63  1961   660330000   446564729
# 64  1960   667070000   435990338
#
# [65 rows x 3 columns]

# %%
df_long = pd.concat([df_C, df_I], \
                    ignore_index=True)
df_long
# Out:
#      date         pop
# 0    2024  1408975000
# 1    2023  1410710000
# 2    2022  1412175000
# 3    2021  1412360000
# 4    2020  1411100000
# ..    ...         ...
# 125  1964   479229598
# 126  1963   468138575
# 127  1962   457283090
# 128  1961   446564729
# 129  1960   435990338
#
# [130 rows x 2 columns]
